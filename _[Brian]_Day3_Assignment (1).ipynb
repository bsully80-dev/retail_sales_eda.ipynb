# %%
import pandas as pd

# %%
import pandas as pd

# %%
df=pd.read_csv('retail_sales.csv')

# %%
df.head()
# Out:
#    Transaction_ID        Date       City     Product  Units  Price   Revenue
# 0            1001  2026-08-01  Hyderabad      Laptop    2.0  55000  110000.0
# 1            1002  2026-08-01     Mumbai  Smartphone    4.0  28000  112000.0
# 2            1003  2026-08-02      Delhi      Tablet    5.0  18000   90000.0
# 3            1004  2026-08-02  Bengaluru     Monitor    3.0  16000   48000.0
# 4            1005  2026-08-03  Hyderabad  Smartphone    6.0  28000  168000.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  41 non-null     int64
#  1   Date            41 non-null     str
#  2   City            41 non-null     str
#  3   Product         41 non-null     str
#  4   Units           40 non-null     float64
#  5   Price           41 non-null     int64
#  6   Revenue         40 non-null     float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 3.4 KB

# %%
df.describe()
# Out:
#        Transaction_ID      Units         Price        Revenue
# count       41.000000  40.000000     41.000000      40.000000
# mean      1020.951220   3.800000  31073.170732  103250.000000
# std         11.899477   1.381192  16245.599779   34009.614025
# min       1001.000000   1.000000  16000.000000   48000.000000
# 25%       1011.000000   3.000000  18000.000000   78000.000000
# 50%       1021.000000   4.000000  28000.000000  110000.000000
# 75%       1031.000000   5.000000  55000.000000  112000.000000
# max       1040.000000   6.000000  55000.000000  168000.000000

# %%
df.isnull().sum()
# Out:
# Transaction_ID    0
# Date              0
# City              0
# Product           0
# Units             1
# Price             0
# Revenue           1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df["Product"]=df["Product"].str.lower().str.strip()

# %%
df["Product"]
# Out:
# 0         laptop
# 1     smartphone
# 2         tablet
# 3        monitor
# 4     smartphone
# 5         laptop
# 6     smartphone
# 7         laptop
# 8         tablet
# 9        monitor
# 10        laptop
# 11    smartphone
# 12       monitor
# 13        tablet
# 14       monitor
# 15        tablet
# 16        laptop
# 17    smartphone
# 18        tablet
# 19       monitor
# 20    smartphone
# 21        laptop
# 22    smartphone
# 23        laptop
# 24        tablet
# 25       monitor
# 26        laptop
# 27    smartphone
# 28       monitor
# 29        tablet
# 30       monitor
# 31        tablet
# 32        laptop
# 33    smartphone
# 34    smartphone
# 35        laptop
# 36        tablet
# 37       monitor
# 38        laptop
# 39    smartphone
# 40        laptop
# Name: Product, dtype: str

# %%
df["Product"].unique()
# Out:
# <ArrowStringArray>
# ['laptop', 'smartphone', 'tablet', 'monitor']
# Length: 4, dtype: str

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
Q1=df["Price"].quantile(0.25)
Q3=df["Price"].quantile(0.75)
IQR=Q3-Q1

# %%
import seaborn as sns

# %%
sns.histplot(df["Price"],bins=5,kde=True)
plt.title("Distibution of Price")
plt.show()

# %%
sns.countplot(x="City",data=df,palette="Set2")
plt.title("Price Count by City")
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_4880\1794793556.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="City",data=df,palette="Set2")
# Text(0.5, 1.0, 'Price Count by City')

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plt.figure(figsize=(6,4))
#       2 sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm",fmt=".2f")
#       3 plt.title("Correlation Matrix")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
#Conclude: Write a 3-sentence business recommendation based on your findings.

#Based on my analysis, it is clear that Delhi and Bengaluru City are the most profitable locations, so action steps could be how to target the lower performing cities and what lessons can we learn from our success in both top locations. It also looking like there is a downward direction over the last few years in overall sales.
